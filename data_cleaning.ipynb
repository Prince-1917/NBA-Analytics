# %%
import pandas as pd
import numpy as np

# %%
games_details= pd.read_csv('games_details.csv')
games=pd.read_csv('games.csv')
players=pd.read_csv('players.csv')
ranking=pd.read_csv('ranking.csv')
teams=pd.read_csv('teams.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 games_details= pd.read_csv('games_details.csv')
#       2 games=pd.read_csv('games.csv')
#       3 players=pd.read_csv('players.csv')
#
# ...

# %%
games_details.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  DREB  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0   1.0
# 1   Jeremy Sochan   Jeremy              F     NaN  31:01  ...   6.0   3.0
# 2    Jakob Poeltl    Jakob              C     NaN  21:42  ...   1.0   3.0
# 3   Devin Vassell    Devin              G     NaN  30:20  ...   0.0   9.0
# 4       Tre Jones      Tre              G     NaN  27:44  ...   0.0   2.0
#
#    REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0  2.0  0.0  1.0  0.0  2.0  5.0   2.0        -2.0
# ...

# %%
games_details.shape
# Out:
# (668628, 29)

# %%
games_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668628 entries, 0 to 668627
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   GAME_ID            668628 non-null  int64
#  1   TEAM_ID            668628 non-null  int64
#  2   TEAM_ABBREVIATION  668628 non-null  object
#  3   TEAM_CITY          668628 non-null  object
#  4   PLAYER_ID          668628 non-null  int64
#  5   PLAYER_NAME        668628 non-null  object
#  6   NICKNAME           53037 non-null   object
#  7   START_POSITION     255765 non-null  object
#  8   COMMENT            109689 non-null  object
#  9   MIN                558938 non-null  object
#  10  FGM                558938 non-null  float64
#  11  FGA                558938 non-null  float64
#  12  FG_PCT             558938 non-null  float64
#  13  FG3M               558938 non-null  float64
#  14  FG3A               558938 non-null  float64
# ...

# %%
teams.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
teams.shape
# Out:
# (30, 14)

# %%
ranking.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G  \
# 0  1610612743          0      22022    2022-12-22       West       Denver  30
# 1  1610612763          0      22022    2022-12-22       West      Memphis  30
# 2  1610612740          0      22022    2022-12-22       West  New Orleans  31
# 3  1610612756          0      22022    2022-12-22       West      Phoenix  32
# 4  1610612746          0      22022    2022-12-22       West  LA Clippers  33
#
#     W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  19  11  0.633        10-3         9-8           NaN
# 1  19  11  0.633        13-2         6-9           NaN
# 2  19  12  0.613        13-4         6-8           NaN
# 3  19  13  0.594        14-4         5-9           NaN
# 4  19  14  0.576        11-7         8-7           NaN

# %%
ranking.shape
# Out:
# (210342, 13)

# %%
ranking['STANDINGSDATE'].unique().shape
# Out:
# (7023,)

# %%
players.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
players.shape
# Out:
# (7228, 4)

# %%
players['PLAYER_ID'].unique().shape
# Out:
# (1769,)

# %%
games.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2022    1610612740     126.0        0.484        0.926  ...      25.0
# 1    2022    1610612762     120.0        0.488        0.952  ...      16.0
# 2    2022    1610612739     114.0        0.482        0.786  ...      22.0
# 3    2022    1610612755     113.0        0.441        0.909  ...      27.0
# 4    2022    1610612737     108.0        0.429        1.000  ...      22.0
#
# ...

# %%
games.shape
# Out:
# (26651, 21)

# %%
teams.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
teams.isnull().sum()
# Out:
# LEAGUE_ID             0
# TEAM_ID               0
# MIN_YEAR              0
# MAX_YEAR              0
# ABBREVIATION          0
# NICKNAME              0
# YEARFOUNDED           0
# CITY                  0
# ARENA                 0
# ARENACAPACITY         4
# OWNER                 0
# GENERALMANAGER        0
# HEADCOACH             0
# DLEAGUEAFFILIATION    0
# dtype: int64

# %%
teams['LEAGUE_ID'].unique()
# Out:
# array([0])

# %%
teams= teams.drop(columns=['LEAGUE_ID'])

# %%
teams.head()
# Out:
#       TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  YEARFOUNDED  \
# 0  1610612737      1949      2019          ATL      Hawks         1949
# 1  1610612738      1946      2019          BOS    Celtics         1946
# 2  1610612740      2002      2019          NOP   Pelicans         2002
# 3  1610612741      1966      2019          CHI      Bulls         1966
# 4  1610612742      1980      2019          DAL  Mavericks         1980
#
#           CITY                     ARENA  ARENACAPACITY            OWNER  \
# 0      Atlanta          State Farm Arena        18729.0     Tony Ressler
# 1       Boston                 TD Garden        18624.0    Wyc Grousbeck
# 2  New Orleans      Smoothie King Center            NaN       Tom Benson
# 3      Chicago             United Center        21711.0  Jerry Reinsdorf
# 4       Dallas  American Airlines Center        19200.0       Mark Cuban
#
#    GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
teams['ARENACAPACITY'].isnull
# Out:
# <bound method Series.isnull of 0     18729.0
# 1     18624.0
# 2         NaN
# 3     21711.0
# 4     19200.0
# 5     19099.0
# 6     18104.0
# 7     19060.0
# 8     19060.0
# 9     19600.0
# 10    17500.0
# 11    19356.0
# 12        NaN
# 13    19763.0
# 14        0.0
# 15    18345.0
# 16        NaN
# 17        NaN
# 18    19980.0
# 19    17500.0
# 20    18694.0
# 21    19163.0
# 22    19800.0
# 23    20148.0
# 24    18119.0
# 25    20647.0
# 26    21000.0
# 27    19026.0
# 28    20562.0
# 29    19596.0
# Name: ARENACAPACITY, dtype: float64>

# %%
teams.loc[teams['ARENACAPACITY'].isna(), ['TEAM_ID','CITY','NICKNAME','ARENA','ARENACAPACITY']]
# Out:
#        TEAM_ID          CITY  NICKNAME                       ARENA  \
# 2   1610612740   New Orleans  Pelicans        Smoothie King Center
# 12  1610612751      Brooklyn      Nets             Barclays Center
# 16  1610612755  Philadelphia     76ers          Wells Fargo Center
# 17  1610612756       Phoenix      Suns  Talking Stick Resort Arena
#
#     ARENACAPACITY
# 2             NaN
# 12            NaN
# 16            NaN
# 17            NaN

# %%
teams.loc[teams['ARENACAPACITY']==0,  ['TEAM_ID','CITY','NICKNAME','ARENA','ARENACAPACITY']]
# Out:
#        TEAM_ID     CITY NICKNAME         ARENA  ARENACAPACITY
# 14  1610612753  Orlando    Magic  Amway Center            0.0

# %%
teams.loc[teams['ARENA']=='Amway Center', ['TEAM_ID','CITY','NICKNAME','ARENA','ARENACAPACITY']]
# Out:
#        TEAM_ID     CITY NICKNAME         ARENA  ARENACAPACITY
# 14  1610612753  Orlando    Magic  Amway Center            0.0

# %%
teams.loc[teams['ARENA']=='Smoothie King Center', ['TEAM_ID','CITY','NICKNAME','ARENA','ARENACAPACITY']]
# Out:
#       TEAM_ID         CITY  NICKNAME                 ARENA  ARENACAPACITY
# 2  1610612740  New Orleans  Pelicans  Smoothie King Center            NaN

# %%
teams.loc[teams['CITY']=='New Orleans']
# Out:
#       TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION  NICKNAME  YEARFOUNDED  \
# 2  1610612740      2002      2019          NOP  Pelicans         2002
#
#           CITY                 ARENA  ARENACAPACITY       OWNER  \
# 2  New Orleans  Smoothie King Center            NaN  Tom Benson
#
#    GENERALMANAGER     HEADCOACH DLEAGUEAFFILIATION
# 2  Trajan Langdon  Alvin Gentry       No Affiliate

# %%
teams.describe()
# Out:
#             TEAM_ID     MIN_YEAR  MAX_YEAR  YEARFOUNDED  ARENACAPACITY
# count  3.000000e+01    30.000000      30.0    30.000000      26.000000
# mean   1.610613e+09  1969.700000    2019.0  1969.700000   18553.307692
# std    8.803408e+00    16.698441       0.0    16.698441    3916.923362
# min    1.610613e+09  1946.000000    2019.0  1946.000000       0.000000
# 25%    1.610613e+09  1952.000000    2019.0  1952.000000   18641.500000
# 50%    1.610613e+09  1970.000000    2019.0  1970.000000   19131.000000
# 75%    1.610613e+09  1979.000000    2019.0  1979.000000   19790.750000
# max    1.610613e+09  2002.000000    2019.0  2002.000000   21711.000000

# %%
median_capacity=teams.loc[teams['ARENACAPACITY'].notna() & (teams['ARENACAPACITY']>0), 'ARENACAPACITY'].median()
print(median_capacity)
# Out:
# 19163.0

# %%
teams['ARENACAPACITY']= teams['ARENACAPACITY'].replace(0, median_capacity)
teams['ARENACAPACITY']=teams['ARENACAPACITY'].fillna(median_capacity)

# %%
teams['ARENACAPACITY'].isna().sum()
# Out:
# np.int64(0)

# %%
(teams['ARENACAPACITY']==0).sum()
# Out:
# np.int64(0)

# %%
teams.head()
# Out:
#       TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  YEARFOUNDED  \
# 0  1610612737      1949      2019          ATL      Hawks         1949
# 1  1610612738      1946      2019          BOS    Celtics         1946
# 2  1610612740      2002      2019          NOP   Pelicans         2002
# 3  1610612741      1966      2019          CHI      Bulls         1966
# 4  1610612742      1980      2019          DAL  Mavericks         1980
#
#           CITY                     ARENA  ARENACAPACITY            OWNER  \
# 0      Atlanta          State Farm Arena        18729.0     Tony Ressler
# 1       Boston                 TD Garden        18624.0    Wyc Grousbeck
# 2  New Orleans      Smoothie King Center        19163.0       Tom Benson
# 3      Chicago             United Center        21711.0  Jerry Reinsdorf
# 4       Dallas  American Airlines Center        19200.0       Mark Cuban
#
#    GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
teams.isnull().sum()
# Out:
# TEAM_ID               0
# MIN_YEAR              0
# MAX_YEAR              0
# ABBREVIATION          0
# NICKNAME              0
# YEARFOUNDED           0
# CITY                  0
# ARENA                 0
# ARENACAPACITY         0
# OWNER                 0
# GENERALMANAGER        0
# HEADCOACH             0
# DLEAGUEAFFILIATION    0
# dtype: int64

# %%
teams.duplicated().sum()
# Out:
# np.int64(0)

# %%
ranking.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G  \
# 0  1610612743          0      22022    2022-12-22       West       Denver  30
# 1  1610612763          0      22022    2022-12-22       West      Memphis  30
# 2  1610612740          0      22022    2022-12-22       West  New Orleans  31
# 3  1610612756          0      22022    2022-12-22       West      Phoenix  32
# 4  1610612746          0      22022    2022-12-22       West  LA Clippers  33
#
#     W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  19  11  0.633        10-3         9-8           NaN
# 1  19  11  0.633        13-2         6-9           NaN
# 2  19  12  0.613        13-4         6-8           NaN
# 3  19  13  0.594        14-4         5-9           NaN
# 4  19  14  0.576        11-7         8-7           NaN

# %%
ranking.isnull().sum()
# Out:
# TEAM_ID               0
# LEAGUE_ID             0
# SEASON_ID             0
# STANDINGSDATE         0
# CONFERENCE            0
# TEAM                  0
# G                     0
# W                     0
# L                     0
# W_PCT                 0
# HOME_RECORD           0
# ROAD_RECORD           0
# RETURNTOPLAY     206352
# dtype: int64

# %%
ranking= ranking.drop(columns=['LEAGUE_ID','RETURNTOPLAY'])

# %%
ranking.head()
# Out:
#       TEAM_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G   W   L  \
# 0  1610612743      22022    2022-12-22       West       Denver  30  19  11
# 1  1610612763      22022    2022-12-22       West      Memphis  30  19  11
# 2  1610612740      22022    2022-12-22       West  New Orleans  31  19  12
# 3  1610612756      22022    2022-12-22       West      Phoenix  32  19  13
# 4  1610612746      22022    2022-12-22       West  LA Clippers  33  19  14
#
#    W_PCT HOME_RECORD ROAD_RECORD
# 0  0.633        10-3         9-8
# 1  0.633        13-2         6-9
# 2  0.613        13-4         6-8
# 3  0.594        14-4         5-9
# 4  0.576        11-7         8-7

# %%
ranking.duplicated().sum()
# Out:
# np.int64(0)

# %%
players.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
players.shape
# Out:
# (7228, 4)

# %%
players.isnull().sum()
# Out:
# PLAYER_NAME    0
# TEAM_ID        0
# PLAYER_ID      0
# SEASON         0
# dtype: int64

# %%
players.duplicated().sum()
# Out:
# np.int64(0)

# %%
players['PLAYER_ID'].is_unique
# Out:
# False

# %%
players['PLAYER_ID'].duplicated().sum()
# Out:
# np.int64(5459)

# %%
players.loc[
    players['PLAYER_ID'].duplicated(keep=False),
    ['PLAYER_ID','TEAM_ID','SEASON']
].sort_values(by=['PLAYER_ID','SEASON'])
# Out:
#       PLAYER_ID     TEAM_ID  SEASON
# 6657        255  1610612756    2009
# 6274        255  1610612756    2010
# 5830        255  1610612756    2011
# 4948        255  1610612746    2012
# 6683        406  1610612739    2009
# ...         ...         ...     ...
# 549     1629353  1610612753    2019
# 416     1629610  1610612758    2019
# 550     1629610  1610612753    2019
# 62      1629622  1610612741    2019
# 574     1629622  1610612738    2019
#
# [6688 rows x 3 columns]

# %%
players[['PLAYER_ID', 'SEASON']].duplicated().sum()
# Out:
# np.int64(923)

# %%
players.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
players[['PLAYER_ID', 'TEAM_ID', 'SEASON']].duplicated().sum()
# Out:
# np.int64(0)

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7228 entries, 0 to 7227
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PLAYER_NAME  7228 non-null   object
#  1   TEAM_ID      7228 non-null   int64
#  2   PLAYER_ID    7228 non-null   int64
#  3   SEASON       7228 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 226.0+ KB

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26651 entries, 0 to 26650
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     26651 non-null  object
#  1   GAME_ID           26651 non-null  int64
#  2   GAME_STATUS_TEXT  26651 non-null  object
#  3   HOME_TEAM_ID      26651 non-null  int64
#  4   VISITOR_TEAM_ID   26651 non-null  int64
#  5   SEASON            26651 non-null  int64
#  6   TEAM_ID_home      26651 non-null  int64
#  7   PTS_home          26552 non-null  float64
#  8   FG_PCT_home       26552 non-null  float64
#  9   FT_PCT_home       26552 non-null  float64
#  10  FG3_PCT_home      26552 non-null  float64
#  11  AST_home          26552 non-null  float64
#  12  REB_home          26552 non-null  float64
#  13  TEAM_ID_away      26651 non-null  int64
#  14  PTS_away          26552 non-null  float64
#  15  FG_PCT_away       26552 non-null  float64
# ...

# %%
games.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2022    1610612740     126.0        0.484        0.926  ...      25.0
# 1    2022    1610612762     120.0        0.488        0.952  ...      16.0
# 2    2022    1610612739     114.0        0.482        0.786  ...      22.0
# 3    2022    1610612755     113.0        0.441        0.909  ...      27.0
# 4    2022    1610612737     108.0        0.429        1.000  ...      22.0
#
# ...

# %%
games['GAME_DATE_EST']=pd.to_datetime(games['GAME_DATE_EST'])
games['GAME_DATE_EST'].dtype
# Out:
# dtype('<M8[ns]')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26651 entries, 0 to 26650
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     26651 non-null  datetime64[ns]
#  1   GAME_ID           26651 non-null  int64
#  2   GAME_STATUS_TEXT  26651 non-null  object
#  3   HOME_TEAM_ID      26651 non-null  int64
#  4   VISITOR_TEAM_ID   26651 non-null  int64
#  5   SEASON            26651 non-null  int32
#  6   TEAM_ID_home      26651 non-null  int64
#  7   PTS_home          26552 non-null  float64
#  8   FG_PCT_home       26552 non-null  float64
#  9   FT_PCT_home       26552 non-null  float64
#  10  FG3_PCT_home      26552 non-null  float64
#  11  AST_home          26552 non-null  float64
#  12  REB_home          26552 non-null  float64
#  13  TEAM_ID_away      26651 non-null  int64
#  14  PTS_away          26552 non-null  float64
#  15  FG_PCT_away       26552 non-null  float64
# ...

# %%
games.shape
# Out:
# (26651, 21)

# %%
games.isnull().sum()
# Out:
# GAME_DATE_EST        0
# GAME_ID              0
# GAME_STATUS_TEXT     0
# HOME_TEAM_ID         0
# VISITOR_TEAM_ID      0
# SEASON               0
# TEAM_ID_home         0
# PTS_home            99
# FG_PCT_home         99
# FT_PCT_home         99
# FG3_PCT_home        99
# AST_home            99
# REB_home            99
# TEAM_ID_away         0
# PTS_away            99
# FG_PCT_away         99
# FT_PCT_away         99
# FG3_PCT_away        99
# AST_away            99
# REB_away            99
# HOME_TEAM_WINS       0
# dtype: int64

# %%
games.loc[games['PTS_home'].isna(), 'GAME_STATUS_TEXT'].value_counts()
# Out:
# GAME_STATUS_TEXT
# Final    99
# Name: count, dtype: int64

# %%
games=games.dropna(
    subset=['PTS_home','PTS_away',
        'FG_PCT_home', 'FG_PCT_away',
        'FT_PCT_home', 'FT_PCT_away',
        'FG3_PCT_home', 'FG3_PCT_away']
)

# %%
games.isna().sum()
# Out:
# GAME_DATE_EST       0
# GAME_ID             0
# GAME_STATUS_TEXT    0
# HOME_TEAM_ID        0
# VISITOR_TEAM_ID     0
# SEASON              0
# TEAM_ID_home        0
# PTS_home            0
# FG_PCT_home         0
# FT_PCT_home         0
# FG3_PCT_home        0
# AST_home            0
# REB_home            0
# TEAM_ID_away        0
# PTS_away            0
# FG_PCT_away         0
# FT_PCT_away         0
# FG3_PCT_away        0
# AST_away            0
# REB_away            0
# HOME_TEAM_WINS      0
# dtype: int64

# %%
games_details.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  DREB  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0   1.0
# 1   Jeremy Sochan   Jeremy              F     NaN  31:01  ...   6.0   3.0
# 2    Jakob Poeltl    Jakob              C     NaN  21:42  ...   1.0   3.0
# 3   Devin Vassell    Devin              G     NaN  30:20  ...   0.0   9.0
# 4       Tre Jones      Tre              G     NaN  27:44  ...   0.0   2.0
#
#    REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0  2.0  0.0  1.0  0.0  2.0  5.0   2.0        -2.0
# ...

# %%
games_details.isnull().sum()
# Out:
# GAME_ID                   0
# TEAM_ID                   0
# TEAM_ABBREVIATION         0
# TEAM_CITY                 0
# PLAYER_ID                 0
# PLAYER_NAME               0
# NICKNAME             615591
# START_POSITION       412863
# COMMENT              558939
# MIN                  109690
# FGM                  109690
# FGA                  109690
# FG_PCT               109690
# FG3M                 109690
# FG3A                 109690
# FG3_PCT              109690
# FTM                  109690
# FTA                  109690
# FT_PCT               109690
# OREB                 109690
# DREB                 109690
# REB                  109690
# AST                  109690
# STL                  109690
# BLK                  109690
# TO                   109690
# PF                   109690
# PTS                  109690
# PLUS_MINUS           133351
# dtype: int64

# %%
games_details= games_details.drop(columns=['NICKNAME'])

# %%
games_details['COMMENT'].value_counts()
print(f"Unique comments: {games_details['COMMENT'].nunique()}")
print(f"Comments: \n {games_details['COMMENT'].unique()}")
# Out:
# Unique comments: 5348
# Comments:
#  [nan "DNP - Coach's Decision" 'DNP - Injury/Illness' ...
#  'DND - Strained Right Hamstring and Groin'
#  'DND - Strained Right Hamstring/Groin'
#  'DND - Non-Displaced Fracture, Left Fibul']

# %%
games_details['MIN'].dtype
# Out:
# dtype('O')

# %%
games_details.head(10)
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
# 5  22200477  1610612759               SAS  San Antonio    1628380
# 6  22200477  1610612759               SAS  San Antonio     203926
# 7  22200477  1610612759               SAS  San Antonio    1626196
# 8  22200477  1610612759               SAS  San Antonio    1631103
# 9  22200477  1610612759               SAS  San Antonio    1628966
#
#         PLAYER_NAME START_POSITION COMMENT    MIN  FGM  ...  OREB  DREB  REB  \
# 0    Romeo Langford              F     NaN  18:06  1.0  ...   1.0   1.0  2.0
# 1     Jeremy Sochan              F     NaN  31:01  7.0  ...   6.0   3.0  9.0
# ...

# %%
(games_details['MIN']=='0:00').sum()
# Out:
# np.int64(95)

# %%
(games_details['MIN']=='00:00').sum()
# Out:
# np.int64(0)

# %%
(games_details['MIN']=='0').sum()
# Out:
# np.int64(85)

# %%
player_game_stats= games_details[
    games_details['MIN'].notna() & (games_details['MIN']!='0') & (games_details['MIN']!='0:00')
    ]

# %%
player_game_stats['MIN'].isna().sum()
# Out:
# np.int64(0)

# %%
player_game_stats = games_details[
    games_details['MIN'].notna() &
    (games_details['MIN'].str.strip() != '0:00') &
    (games_details['MIN'].str.strip() != '0')
]

# %%
player_game_stats.shape
# Out:
# (558758, 28)

# %%
games_details.shape
# Out:
# (668628, 28)

# %%
ranking.isnull().sum()
# Out:
# TEAM_ID          0
# SEASON_ID        0
# STANDINGSDATE    0
# CONFERENCE       0
# TEAM             0
# G                0
# W                0
# L                0
# W_PCT            0
# HOME_RECORD      0
# ROAD_RECORD      0
# dtype: int64
